# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Financial Analytics data.csv')
df.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0      1  Reliance Inds.        583436.72           99810.00         NaN
# 1      2             TCS        563709.84           30904.00         NaN
# 2      3       HDFC Bank        482953.59           20581.27         NaN
# 3      4             ITC        320985.27            9772.02         NaN
# 4      5         H D F C        289497.37           16840.51         NaN

# %%
len(df)
# Out:
# 488

# %%
df['Sales Qtr - Crore'].isna().sum()
# Out:
# 123

# %%
df['Unnamed: 4'].count()
# Out:
# 94

# %%
df['Sales Qtr - Crore'].fillna(df2['Unnamed: 4'], inplace=True)
df[df['Sales Qtr - Crore'].isna()]
# Out:
#      S.No.              Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 49      50     Bharti Infra.         61776.92                NaN         NaN
# 99     100     Colgate-Palm.              NaN                NaN         NaN
# 147    150   Endurance Tech.              NaN                NaN         NaN
# 171    176  Info Edg.(India)         14845.05                NaN         NaN
# 185    192     Max Financial         13401.76                NaN         NaN
# 193    200   Natl. Aluminium              NaN                NaN         NaN
# 224    231     Bombay Burmah         10864.53                NaN         NaN
# 241    248  Sundaram Clayton         10074.36                NaN         NaN
# 243    250     Mahanagar Gas              NaN                NaN         NaN
# 258    271      Mahindra CIE          8587.04                NaN         NaN
# 287    300        Bajaj Corp              NaN                NaN         NaN
# ...

# %%
df.drop(['Unnamed: 4'], axis = 'columns', inplace = True)

# %%
df['Sales Qtr - Crore'].isna().sum()
# Out:
# 29

# %%
### 29 rows out of 488 can be removed ###

# %%
df[df.isna().any(axis='columns')]
# Out:
#      S.No.              Name  Mar Cap - Crore  Sales Qtr - Crore
# 49      50     Bharti Infra.         61776.92                NaN
# 99     100     Colgate-Palm.              NaN                NaN
# 147    150   Endurance Tech.              NaN                NaN
# 171    176  Info Edg.(India)         14845.05                NaN
# 185    192     Max Financial         13401.76                NaN
# 193    200   Natl. Aluminium              NaN                NaN
# 224    231     Bombay Burmah         10864.53                NaN
# 241    248  Sundaram Clayton         10074.36                NaN
# 243    250     Mahanagar Gas              NaN                NaN
# 258    271      Mahindra CIE          8587.04                NaN
# 287    300        Bajaj Corp              NaN                NaN
# 314    327      Prism Cement          6176.23                NaN
# 332    345          GE Power          5497.40                NaN
# ...

# %%
df.dropna(thresh = 3, inplace = True)

# %%
df
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 0        1   Reliance Inds.        583436.72           99810.00
# 1        2              TCS        563709.84           30904.00
# 2        3        HDFC Bank        482953.59           20581.27
# 3        4              ITC        320985.27            9772.02
# 4        5          H D F C        289497.37           16840.51
# ..     ...              ...              ...                ...
# 482    495      Prime Focus          3031.50             609.61
# 483    496  Lak. Vilas Bank          3029.57             790.17
# 484    497            NOCIL          3026.26             249.27
# 485    498    Orient Cement          3024.32             511.53
# 486    499  Natl.Fertilizer          3017.07            2840.75
#
# [479 rows x 4 columns]

# %%
df.drop(['S.No.'], axis = 'columns', inplace = True)
df
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore
# 0     Reliance Inds.        583436.72           99810.00
# 1                TCS        563709.84           30904.00
# 2          HDFC Bank        482953.59           20581.27
# 3                ITC        320985.27            9772.02
# 4            H D F C        289497.37           16840.51
# ..               ...              ...                ...
# 482      Prime Focus          3031.50             609.61
# 483  Lak. Vilas Bank          3029.57             790.17
# 484            NOCIL          3026.26             249.27
# 485    Orient Cement          3024.32             511.53
# 486  Natl.Fertilizer          3017.07            2840.75
#
# [479 rows x 3 columns]

# %%
df.dropna(thresh = 3, inplace = True)

# %%
plt.scatter(df['Mar Cap - Crore'], df['Sales Qtr - Crore'], marker = 'x')
plt.xlabel('Market Capitalization (crores)')
plt.ylabel('Quarterly Sales (crores)')
plt.title('Market Cap vs Quarterly Sales')
plt.xlim([0,100000])
plt.ylim([0,20000])
plt.show()

# %%
### Most companies have low market cap and low quarterly sales ###

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['Mar Cap - Crore']]
y = df['Sales Qtr - Crore']
x
# Out:
#      Mar Cap - Crore
# 0          583436.72
# 1          563709.84
# 2          482953.59
# 3          320985.27
# 4          289497.37
# ..               ...
# 482          3031.50
# 483          3029.57
# 484          3026.26
# 485          3024.32
# 486          3017.07
#
# [459 rows x 1 columns]

# %%
y
# Out:
# 0      99810.00
# 1      30904.00
# 2      20581.27
# 3       9772.02
# 4      16840.51
#          ...
# 482      609.61
# 483      790.17
# 484      249.27
# 485      511.53
# 486     2840.75
# Name: Sales Qtr - Crore, Length: 459, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
x_train
# Out:
#      Mar Cap - Crore
# 303          6646.41
# 73          39047.57
# 10         203802.35
# 204         11966.83
# 126         22915.42
# ..               ...
# 83          34620.19
# 196         12942.25
# 341          5224.11
# 55          57748.98
# 439          3734.06
#
# [367 rows x 1 columns]

# %%
import sklearn
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test, y_test)
# Out:
# 0.4725580851221508

# %%
#### no linear relation between market cap and quarterly sales ####

# %%
### in general, when market cap is low, the quarterly sales are low too ###
